# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("orders.csv")

print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.head() # shows top 5 rows of data
df.tail() # shows last 5 rows of dataframe
df.info() # gives general information about df
df.describe() # describes the data
df.index  # tells about the index on df, its start, stop & step
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     object
#  2   Product       40 non-null     object
#  3   Category      40 non-null     object
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     object
#  7   Shipped       40 non-null     object
#  8   Country       40 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.9+ KB
# RangeIndex(start=0, stop=40, step=1)

# %%
df.columns # lists all the columns of df
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df["Country"] # gives all the values of Country column

len(df["Country"]) # gives length of all values in country column
# Out:
# 40

# %%
a = df[["Country", "Price"]].head(10)
df[["Country", "Price"]].tail(10) # for multiple columns, we need to pass names as list to the df[]
# Out:
#         Country  Price
# 30      Morocco   32.0
# 31      Germany  140.0
# 32     Colombia   42.0
# 33          USA    0.8
# 34        Japan   55.0
# 35           UK   68.0
# 36     Portugal  125.0
# 37         Iran   28.0
# 38  South Korea   18.0
# 39      Ukraine   35.0

# %%
a.head(5) # referenced data frame from previous cell
# Out:
#      Country   Price
# 0        USA  1200.0
# 1     Canada   150.0
# 2        UAE   300.0
# 3  Singapore    45.0
# 4     Mexico    80.0

# %%
# index value based on rows

df.iloc[0] # gives all values in 0th row
# Out:
# OrderID                1001
# CustomerName     John Smith
# Product              Laptop
# Category        Electronics
# Quantity                  1
# Price                1200.0
# OrderDate        2024-06-01
# Shipped                 Yes
# Country                 USA
# Name: 0, dtype: object

# %%
list(df.iloc[0]) # gives list of all values in 0th row
# datatype of this is different than built in data type of python, so need to be used carefully
# Out:
# [np.int64(1001),
#  'John Smith',
#  'Laptop',
#  'Electronics',
#  np.int64(1),
#  np.float64(1200.0),
#  '2024-06-01',
#  'Yes',
#  'USA']

# %%
print(df.iloc[0]["Country"])  # show the value of country column for 0th Row

print(df["Country"][0])       # show the value of country column for 0th Row
# Out:
# USA
# USA

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
# show data where Category is Electronics and Country is USA

df[(df["Category"] == "Electronics") & (df["Country"] == "USA")]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
# show data where Category is Electronics OR Country is USA

df[(df["Category"] == "Electronics") | (df["Country"] == "USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
df[df["Quantity"] < 20]
df[df["Quantity"] != 20]
df[df["Quantity"] > 100]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerName, Product, Category, Quantity, Price, OrderDate, Shipped, Country]
# Index: []

# %%
df[df["CustomerName"].str.startswith("Am")]
# Out:
#     OrderID  CustomerName  Product     Category  Quantity  Price   OrderDate  \
# 30     1031  Amira Hassan  USB Hub  Electronics         1   32.0  2024-07-02
#
#    Shipped  Country
# 30     Yes  Morocco

# %%
df[df["Country"].isin(["USA", "Brazil"])]
# Out:
#     OrderID    CustomerName            Product     Category  Quantity   Price  \
# 0      1001      John Smith             Laptop  Electronics         1  1200.0
# 17     1018   Michael Brown     Desk Organizer    Furniture         1    65.0
# 21     1022  Isabella Silva  Bluetooth Speaker  Electronics         1    95.0
# 33     1034    Alex Johnson        Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 21  2024-06-23     Yes  Brazil
# 33  2024-07-05     Yes     USA

# %%
df[~df["Country"].isin(["USA", "Brazil"])] # notice the ~ sign -> it produces data for countries not in USA, Brazil
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %%
df.loc[df["CustomerName"] == "Anna Ivanova"]
# Out:
#     OrderID  CustomerName     Product   Category  Quantity  Price   OrderDate  \
# 39     1040  Anna Ivanova  Desk Clock  Furniture         1   35.0  2024-07-11
#
#    Shipped  Country
# 39     Yes  Ukraine

# %%
df.loc[df["CustomerName"] == "Anna Ivanova", "CustomerName"] = "Deepesh" # update data in particular searched row
df.loc[df["CustomerName"] == "Deepesh"]
# Out:
#     OrderID CustomerName     Product   Category  Quantity  Price   OrderDate  \
# 39     1040      Deepesh  Desk Clock  Furniture         1   35.0  2024-07-11
#
#    Shipped  Country
# 39     Yes  Ukraine

# %%
new_df = df.head(5)
new_df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
new_df.loc[new_df["Country"] == "USA", "Country"] = "United States"
new_df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped        Country (False, Country)
# 0  2024-06-01     Yes  United States    United States
# 1  2024-06-03      No         Canada    United States
# 2  2024-06-04     Yes            UAE    United States
# 3  2024-06-05     Yes      Singapore    United States
# 4  2024-06-06      No         Mexico    United States

# %%
df.head() # since we created a shallow copy of df to new_df -> notice any change in new_df is made to df as well
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped        Country
# 0  2024-06-01     Yes  United States
# 1  2024-06-03      No         Canada
# 2  2024-06-04     Yes            UAE
# 3  2024-06-05     Yes      Singapore
# 4  2024-06-06      No         Mexico

# %%
df = df.drop(38)  # drops the row 39

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 33     1034    Alex Johnson         Index Cards   Stationery       100    0.8
# 34     1035   Yuki Yamamoto       Monitor Stand  Electronics         1   55.0
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
#
#      OrderDate Shipped   Country
# 33  2024-07-05     Yes       USA
# 34  2024-07-06     Yes     Japan
# 35  2024-07-07      No        UK
# 36  2024-07-08     Yes  Portugal
# 37  2024-07-09     Yes      Iran

# %%
df.dropna() # to remove the NA values
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.fillna({"OrderID": 0}, inplace=True)

# %%
df["Country"].value_counts() # gives count of rows grouped by Country column
# Out:
# Country
# Japan            3
# Canada           2
# UK               2
# UAE              2
# France           2
# South Korea      2
# Italy            2
# Germany          2
# USA              2
# Mexico           1
# Singapore        1
# United States    1
# Australia        1
# India            1
# Spain            1
# China            1
# Poland           1
# Egypt            1
# Saudi Arabia     1
# Brazil           1
# Pakistan         1
# Sweden           1
# Argentina        1
# Russia           1
# Morocco          1
# Colombia         1
# Portugal         1
# Iran             1
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].sum()  # gives sum of price grouped by Country

df.sort_values("Price", ascending=True)  # gives df with price sorted in ASC
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 33     1034      Alex Johnson            Index Cards   Stationery       100
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 27     1028       Nina Petrov           Binder Clips   Stationery        12
# 20     1021    David Thompson           Highlighters   Stationery         8
# 23     1024        Zara Ahmed           Sticky Notes   Stationery        15
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 15     1016      Ahmed Hassan          Printer Paper   Stationery        20
# 12     1013       Emma Wilson                Stapler   Stationery         3
# 18     1019       Yuki Tanaka             Calculator  Electronics         1
# 29     1030   Giuseppe Romano          Desk Calendar    Furniture         1
# 26     1027     Miguel Torres         Desk Chair Mat    Furniture         1
# ...

# %%
# to save a df to csv

df.to_csv("newdf.csv", index=False)
