# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("stock_data.csv", parse_dates=["date", "dividend_ex_date"])
df.set_index("date", inplace=True)

# Examples:
daily_returns = df.groupby("ticker")["close"].pct_change()
rolling_vol_20 = daily_returns.groupby(df["ticker"]).rolling(20).std().reset_index(level=0, drop=True)
sector_pe = df.groupby("sector")["pe_ratio"].mean()
